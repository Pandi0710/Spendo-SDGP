# %%
#Importing pandas library
import pandas as pd
#Loading data into a DataFrame
filtered_data=pd.read_csv('/content/drive/MyDrive/SDGP Implementation/filtered_data.csv')

# %%
filtered_data.describe()
# Out:
#              Income          Age   Dependents           Rent  Loan_Repayment  \
# count  9.289000e+03  9289.000000  9289.000000    9289.000000     9289.000000
# mean   4.168908e+04    28.444504     2.008289    9132.142173     2047.808469
# std    4.126642e+04     6.385357     1.423939    9580.445160     4180.000884
# min    1.301187e+03    18.000000     0.000000     260.237467        0.000000
# 25%    1.756521e+04    23.000000     1.000000    3629.174885        0.000000
# 50%    3.008112e+04    28.000000     2.000000    6337.753670        0.000000
# 75%    5.137541e+04    34.000000     3.000000   11218.246053     2643.627666
# max    1.079728e+06    39.000000     4.000000  215945.674703    71235.964355
#
#           Insurance      Groceries     Transport    Eating_Out  Entertainment  \
# count   9289.000000    9289.000000   9289.000000   9289.000000    9289.000000
# mean    1454.417542    5216.918285   2713.115588   1468.183746    1452.623652
# ...

# %%
filtered_data.describe().transpose()
# Out:
#                                   count          mean           std  \
# Income                           9289.0  41689.081028  41266.418376
# Age                              9289.0     28.444504      6.385357
# Dependents                       9289.0      2.008289      1.423939
# Rent                             9289.0   9132.142173   9580.445160
# Loan_Repayment                   9289.0   2047.808469   4180.000884
# Insurance                        9289.0   1454.417542   1522.662849
# Groceries                        9289.0   5216.918285   5129.713716
# Transport                        9289.0   2713.115588   2779.618381
# Eating_Out                       9289.0   1468.183746   1500.586442
# Entertainment                    9289.0   1452.623652   1530.347375
# Utilities                        9289.0   2510.894903   2582.403822
# Healthcare                       9289.0   1671.687046   1678.591702
# Education                        9289.0   2510.584300   3213.089984
# ...

# %%
filtered_data.shape
# Out:
# (9289, 27)

# %%
filtered_data.head()
# Out:
#           Income  Age          Rent  Loan_Repayment    Insurance  \
# 0   26858.596592   34   5371.719318        0.000000   869.522617
# 1   50367.605084   35   7555.140763     4612.103386  2201.800050
# 2  101455.600247   21  15218.340037     6809.441427  4889.418087
# 3   20606.733121   32   6182.019936     3562.488826  1018.589940
# 4   46304.790235   30   9260.958047        0.000000  2130.254825
#
#       Groceries    Transport   Eating_Out  Entertainment    Utilities  ...  \
# 0   2818.444460  1543.018778   649.378103    1050.241738  1626.143346  ...
# 1   6313.222081  3221.396403  1513.814376    1723.306926  3368.457108  ...
# 2  14690.149363  7106.130005  5040.249158    2858.194240  6128.550387  ...
# 3   3066.867220  1170.790666   688.059838     418.233816   921.232717  ...
# 4   5065.627032  2500.054847  2040.310666    1016.613164  2945.433561  ...
#
#    Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# ...

# %%
filtered_data = filtered_data.drop(columns=filtered_data.loc[:, 'Potential_Savings_Groceries':'Potential_Savings_Miscellaneous'].columns)
filtered_data=filtered_data.drop(['Dependents','Occupation','City_Tier','Miscellaneous','Loan_Repayment','Groceries','Desired_Savings_Percentage','Disposable_Income','Desired_Savings','Insurance','Entertainment','Utilities','Age'],axis=1)
filtered_data.describe(include="all").transpose()
# Out:
#              count          mean           std          min           25%  \
# Income      5112.0  41913.573064  43262.760396  1301.187333  17261.639991
# Rent        5112.0   9204.088674   9943.801312   260.237467   3630.873853
# Transport   5112.0   2728.717380   2948.357784    81.228584   1100.187839
# Eating_Out  5112.0   1469.207462   1523.910702    39.437523    565.846594
# Healthcare  5112.0   1677.181533   1741.424410    53.500761    668.028388
# Education   5112.0   2500.048033   3323.287012     0.000000    578.472099
#
#                      50%           75%           max
# Income      29872.735370  51272.858240  1.079728e+06
# Rent         6292.240050  11145.873351  2.159457e+05
# Transport    1903.612752   3320.296815  8.186150e+04
# Eating_Out   1025.793030   1793.581874  2.296261e+04
# Healthcare   1178.053294   2035.794094  3.600153e+04
# Education    1641.318384   3309.968110  8.166509e+04

# %%
# Save the cleaned dataset
filtered_data.to_csv('prepared_data.csv', index=False)

# Download the new file
from google.colab import files
files.download('prepared_data.csv')

# %%
#Importing pandas library
import pandas as pd
#Loading data into a DataFrame
prepared_data=pd.read_csv('/content/drive/MyDrive/SDGP Implementation/prepared_data.csv')

# %%
prepared_data.head()
# Out:
#           Income          Rent    Transport   Eating_Out   Healthcare  \
# 0   26858.596592   5371.719318  1543.018778   649.378103  1137.351325
# 1   50367.605084   7555.140763  3221.396403  1513.814376  2178.515847
# 2  101455.600247  15218.340037  7106.130005  5040.249158  4571.118217
# 3   20606.733121   6182.019936  1170.790666   688.059838   830.237055
# 4   46304.790235   9260.958047  2500.054847  2040.310666  1649.757514
#
#      Education
# 0  1551.723167
# 1  3160.026299
# 2     0.000000
# 3  1939.226547
# 4  3085.991147

# %%
prepared_data.shape
# Out:
# (5112, 6)

# %%
prepared_data.describe()
# Out:
#              Income           Rent     Transport    Eating_Out    Healthcare  \
# count  5.112000e+03    5112.000000   5112.000000   5112.000000   5112.000000
# mean   4.191357e+04    9204.088674   2728.717380   1469.207462   1677.181533
# std    4.326276e+04    9943.801312   2948.357784   1523.910702   1741.424410
# min    1.301187e+03     260.237467     81.228584     39.437523     53.500761
# 25%    1.726164e+04    3630.873853   1100.187839    565.846594    668.028388
# 50%    2.987274e+04    6292.240050   1903.612752   1025.793030   1178.053294
# 75%    5.127286e+04   11145.873351   3320.296815   1793.581874   2035.794094
# max    1.079728e+06  215945.674703  81861.503457  22962.605051  36001.527365
#
#           Education
# count   5112.000000
# mean    2500.048033
# std     3323.287012
# min        0.000000
# 25%      578.472099
# 50%     1641.318384
# 75%     3309.968110
# max    81665.091857

# %%
prepared_data.describe().transpose()
# Out:
#              count          mean           std          min           25%  \
# Income      5112.0  41913.573064  43262.760396  1301.187333  17261.639991
# Rent        5112.0   9204.088674   9943.801312   260.237467   3630.873853
# Transport   5112.0   2728.717380   2948.357784    81.228584   1100.187839
# Eating_Out  5112.0   1469.207462   1523.910702    39.437523    565.846594
# Healthcare  5112.0   1677.181533   1741.424410    53.500761    668.028388
# Education   5112.0   2500.048033   3323.287012     0.000000    578.472099
#
#                      50%           75%           max
# Income      29872.735370  51272.858240  1.079728e+06
# Rent         6292.240050  11145.873351  2.159457e+05
# Transport    1903.612752   3320.296815  8.186150e+04
# Eating_Out   1025.793030   1793.581874  2.296261e+04
# Healthcare   1178.053294   2035.794094  3.600153e+04
# Education    1641.318384   3309.968110  8.166509e+04

# %%
prepared_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5112 entries, 0 to 5111
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Income      5112 non-null   float64
#  1   Rent        5112 non-null   float64
#  2   Transport   5112 non-null   float64
#  3   Eating_Out  5112 non-null   float64
#  4   Healthcare  5112 non-null   float64
#  5   Education   5112 non-null   float64
# dtypes: float64(6)
# memory usage: 239.8 KB
